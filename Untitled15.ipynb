# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaBharsakle/EDS_342_Divya-Bharsakle/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/purchase_data.csv")

# %%
data
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176559.0  Bose SoundSport Headphones               1.0       99.99
# 1   176560.0                Google Phone               1.0      600.00
# 2   176560.0            Wired Headphones               1.0       11.99
# 3   176561.0            Wired Headphones               1.0       11.99
# 4   176562.0        USB-C Charging Cable               1.0       11.95
# ..       ...                         ...               ...         ...
# 64  259329.0    Lightning Charging Cable               1.0       14.95
# 65  259330.0       AA Batteries (4-pack)               2.0        3.84
# 66  259331.0    Apple Airpods Headphones               1.0      150.00
# 67  259332.0    Apple Airpods Headphones               1.0      150.00
# 68  259333.0  Bose SoundSport Headphones               1.0       99.99
#
#          Order Date                        Purchase Address
# 0    4/7/2019 22:30       682 Chestnut St, Boston, MA 02215
# 1   4/12/2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 2   4/12/2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 3    5/30/2019 9:27       333 8th St, Los Angeles, CA 90001
# 4   4/29/2019 13:03  381 Wilson St, San Francisco, CA 94016
# ..              ...                                     ...
# 64   9/5/2019 19:00       480 Lincoln St, Atlanta, GA 30301
# 65  9/25/2019 22:01    763 Washington St, Seattle, WA 98101
# 66   9/29/2019 7:00     770 4th St, New York City, NY 10001
# 67  9/16/2019 19:21          782 Lake St, Atlanta, GA 30301
# 68  9/19/2019 18:03   347 Ridge St, San Francisco, CA 94016
#
# [69 rows x 6 columns]

# %%
# Find NAN
nan_df=data[data.isna().any(axis=1)]
display(nan_df.head())

data=data.dropna(how='all')
data.head()
# Out:
#     Order ID Product  Quantity Ordered  Price Each Order Date Purchase Address
# 36       NaN     NaN               NaN         NaN        NaN              NaN
# 51       NaN     NaN               NaN         NaN        NaN              NaN
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#         Order Date                        Purchase Address
# 0   4/7/2019 22:30       682 Chestnut St, Boston, MA 02215
# 1  4/12/2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 2  4/12/2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 3   5/30/2019 9:27       333 8th St, Los Angeles, CA 90001
# 4  4/29/2019 13:03  381 Wilson St, San Francisco, CA 94016

# %%
data = data[data['Order Date'].str[0:2]!='or']

# %%
data['Quantity Ordered'] = pd.to_numeric(data['Quantity Ordered'])
data['Price Each'] = pd.to_numeric(data['Price Each'])

# %%
data['Month'] = data['Order Date'].str[0:2]
data['Month'] = data['Month'].astype('int32')
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-57363b48f07b> in <cell line: 2>()
#       1 data['Month'] = data['Order Date'].str[0:2]
# ----> 2 data['Month'] = data['Month'].astype('int32')
#       3 data.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '4/'

# %%
import datetime as dt
data['Month 2'] = pd.to_datetime(data['Order Date']).dt.month
data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#         Order Date                        Purchase Address Month  Month 2
# 0   4/7/2019 22:30       682 Chestnut St, Boston, MA 02215    4/        4
# 1  4/12/2019 14:38    669 Spruce St, Los Angeles, CA 90001    4/        4
# 2  4/12/2019 14:38    669 Spruce St, Los Angeles, CA 90001    4/        4
# 3   5/30/2019 9:27       333 8th St, Los Angeles, CA 90001    5/        5
# 4  4/29/2019 13:03  381 Wilson St, San Francisco, CA 94016    4/        4

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

data['City'] = data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#         Order Date                        Purchase Address Month  Month 2  \
# 0   4/7/2019 22:30       682 Chestnut St, Boston, MA 02215    4/        4
# 1  4/12/2019 14:38    669 Spruce St, Los Angeles, CA 90001    4/        4
# 2  4/12/2019 14:38    669 Spruce St, Los Angeles, CA 90001    4/        4
# 3   5/30/2019 9:27       333 8th St, Los Angeles, CA 90001    5/        5
# 4  4/29/2019 13:03  381 Wilson St, San Francisco, CA 94016    4/        4
#
#                   City
# 0         Boston  (MA)
# 1    Los Angeles  (CA)
# 2    Los Angeles  (CA)
# 3    Los Angeles  (CA)
# 4  San Francisco  (CA)

# %%
https://colab.research.google.com/drive/10y3JN0fgZ9oOUtfNB7YDL1kW6fCUKtkP?usp=sharing

# %%
data['Sales'] = data['Quantity Ordered'].astype('int') * data['Price Each'].astype('float')

# %%
data.groupby(['Month']).sum()
# Out:
# <ipython-input-12-9f56799fde73>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Month']).sum()
#         Order ID  Quantity Ordered  Price Each  Month 2    Sales
# Month
# 10      550924.0              11.0       10.67       30    39.69
# 11      740314.0              19.0       13.66       44    65.31
# 12      550635.0              17.0        8.97       36    50.83
# 4/     7335546.0             123.0      885.80      160  1210.76
# 5/      353124.0               2.0      111.98       10   111.98
# 6/      184076.0               1.0       14.95        6    14.95
# 8/      726962.0               9.0       23.92       32    50.83
# 9/     2378802.0              17.0      591.44       90   616.62

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

data['City'] = data['Purchase Address'].apply(lambda x: f"{get_city(x)}")
data.head()
city_max=data.groupby(['City']).sum()
print(max(city_max))
# Out:
# Sales
# <ipython-input-13-b303a3e7536c>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   city_max=data.groupby(['City']).sum()

# %%
df = data[data['Order ID'].duplicated(keep=False)]

# Referenced: https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = df[['Order ID', 'Grouped']].drop_duplicates()
print(df['Grouped'])
# Out:
# 1    Google Phone,Wired Headphones
# 2    Google Phone,Wired Headphones
# Name: Grouped, dtype: object
# <ipython-input-14-2288d8e6336f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('Google Phone', 'Wired Headphones') 1

# %%
product_group = all_data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4815a60ac30b> in <cell line: 1>()
# ----> 1 product_group = all_data.groupby('Product')
#       2 quantity_ordered = product_group.sum()['Quantity Ordered']
#
# NameError: name 'all_data' is not defined

# %%
print(quantity_ordered)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f4cf99168a7a> in <cell line: 1>()
# ----> 1 print(quantity_ordered)
#
# NameError: name 'quantity_ordered' is not defined

# %%
prices = all_data.groupby('Product').mean()['Price Each']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-225049d1ed32> in <cell line: 1>()
# ----> 1 prices = all_data.groupby('Product').mean()['Price Each']
#
# NameError: name 'all_data' is not defined

# %%
print(prices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-07403f631c6b> in <cell line: 1>()
# ----> 1 print(prices)
#
# NameError: name 'prices' is not defined
